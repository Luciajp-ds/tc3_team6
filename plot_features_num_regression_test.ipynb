# %%
import importlib
import toolbox_ML
importlib.reload(toolbox_ML)
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt


df = pd.read_csv("titanic.csv")
umbral_corr = 0.2
target_col = "survived"
pvalue = None
columns = []

toolbox_ML.plot_features_num_regression(df, target_col, columns, umbral_corr, pvalue)
